# %%
# !pip install bs4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 KB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=a93fb81f8390251a08882d0e0f24645971d73219bb7f2edadc2fc4890206caea
#   Stored in directory: /home/leducanh6888778/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# ...

# %%
from bs4 import BeautifulSoup
import requests
import os

# %%
path_NBA_salary = os.path.join(os.getcwd(), 'data', 'NBA_salary.html')
try:
    with open(path_NBA_salary, 'r') as file:
        NBA_salary = file.read()
        
        one_line_content = NBA_salary
        
        # Beautiful Soup transforms a complex HTML document into a complex tree of Python objects
        soup = BeautifulSoup(one_line_content, 'html5lib') # parse the html file
        
        print(soup.prettify())
        
except FileNotFoundError:
    NBA_salary = None
    print('File not found!')
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
def prepare_html_content(path):
    try:
        with open(path, 'r') as html_file:
            html_content = html_file.read()
            html_content = ' '.join(html_content.split())
            html_content = html_content.replace('> <', '><')
            return html_content
    except FileNotFoundError:
        print('File not found')
        return None

# %%
html_content = prepare_html_content(path_NBA_salary)
if html_content:
    soup = BeautifulSoup(html_content, 'html.parser')

# %%
# html element after parse using Soup is like object, we can use tag object in Soup to access it.
title_object = soup.title
print('Title object: ', title_object)
# Out:
# Title object:  <title>Page Title</title>

# %%
print(type(title_object))
# Out:
# <class 'bs4.element.Tag'>

# %%
tag_object = soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_child = tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
parent_tag = tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %%
sibling1 = tag_object.next_sibling
sibling1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling2 = sibling1.next_sibling
sibling2
# Out:
# <h3> Stephen Curry</h3>

# %%
# a html element after parsing using Soup is like an object, more specifically, a dictionary of attributes and values.
# we can access the attributes and values by using the attribute name as a key and the value as a value.
print(tag_child['id'])
print(tag_child.get('id'))
# Out:
# boldest
# boldest

# %%
print(soup.h3.b)
soup.h3.b.attrs
# Out:
# <b id="boldest">Lebron James</b>
# {'id': 'boldest'}

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# Out:
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %%
content_html = prepare_html_content(os.path.join(os.getcwd(), 'data', 'table_content.html'))
print(content_html)
# Out:
# <table><tr><td id='flight'>Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>80 kg</td></tr></table>

# %%
table_bs = BeautifulSoup(content_html, 'html5lib')

# %%
table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>80 kg</td></tr>]

# %%
first_row =table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i,row in enumerate(table_rows):
    print("row",i,"is: {",row,'}')
# Out:
# row 0 is: { <tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr> }
# row 1 is: { <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr> }
# row 2 is: { <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr> }
# row 3 is: { <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>80 kg</td></tr> }

# %%
for i,row in enumerate(table_rows):
    print("row",i)
    cells=row.find_all('td')
    for j,cell in enumerate(cells):
        print('colunm',j,"cell",cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>
# colunm 2 cell <td>80 kg</td>

# %%
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td>,
#  <td>80 kg</td>]

# %%
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %%
table_bs.find_all(href=False)
# Out:
# [<html><head></head><body><table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>80 kg</td></tr></tbody></table></body></html>,
#  <head></head>,
#  <body><table><tbody><tr><td id="flight">Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida</a><a></a></td><td>80 kg</td></tr></tbody></table></body>,
# ...

# %%
soup.find_all(id='boldest')
# Out:
# [<b id="boldest">Lebron James</b>]

# %%
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>
# Out:
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %%
two_tables = prepare_html_content(os.path.join(os.getcwd(), 'data', 'two_tables.html'))
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td><td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td><td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %%
url = "https://www.seek.com.au/jobs/in-Sydney-NSW-2000?keywords=Python%2F%20Django%20Developer"

# %%
data  = requests.get(url).text
data
# Out:
# '<!doctype html>\n<html lang="en" prefix="og: http://ogp.me/ns#">\n  <head>\n  <meta charset="utf-8">\n  <meta name="referrer" content="no-referrer-when-downgrade">\n  <meta name="apple-mobile-web-app-capable" content="yes">\n  <meta name="apple-mobile-web-app-title" content="SEEK">\n  <meta name="mobile-web-app-capable" content="yes">\n  <meta name="request-id" content="MC42NTQxMzczNzI5NzE0MTYy">\n  <meta name="theme-color" content="#fff">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <link rel="icon" href="/static/shared-web/favicon-4e1897dfd0901e8a3bf7e604d3a90636.ico">\n<link rel="apple-touch-icon" href="/static/shared-web/iphone-7c4d7dcb05fece466d8901945e36bbaa.png">\n<link rel="apple-touch-icon" sizes="76x76" href="/static/shared-web/ipad-96988dd1c0902fd20b34ce260d03729b.png">\n<link rel="apple-touch-icon" sizes="120x120" href="/static/shared-web/iphoneRetina-c772d091f011ef7ce26f631360de4907.png">\n<link rel="apple-touch-icon" sizes="152x152" href="
# ...

# %%
soup = BeautifulSoup(data,"html5lib")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns#"><head>
#   <meta charset="utf-8"/>
#   <meta content="no-referrer-when-downgrade" name="referrer"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="SEEK" name="apple-mobile-web-app-title"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="MC42NTQxMzczNzI5NzE0MTYy" name="request-id"/>
#   <meta content="#fff" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/static/shared-web/favicon-4e1897dfd0901e8a3bf7e604d3a90636.ico" rel="icon"/>
# <link href="/static/shared-web/iphone-7c4d7dcb05fece466d8901945e36bbaa.png" rel="apple-touch-icon"/>
# <link href="/static/shared-web/ipad-96988dd1c0902fd20b34ce260d03729b.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/static/shared-web/iphoneRetina-c772d091f011ef7ce26f631360de4907.png" rel="apple-touch-icon" sizes="120x120"/>
# ...

# %%
# Scrape all links
for link in soup.find_all('a', href=True):
    print(link['href'])
# Out:
# /jobs/in-Sydney-NSW-2000#start-of-content
# /
# /learning/?campaigncode=seek_banner_29&sc_trk=skj-courses-link
# https://www.seekbusiness.com.au/?tracking=sk%3Amain%3Aau%3Anav%3Abus
# https://www.volunteer.com.au/?tracking=SKMAU%3Amain+header
# /
# /
# /profile/
# /career-advice/
# /companies/
# /oauth/login/?returnUrl=https%3A%2F%2Fwww.seek.com.au%2Fjobs%2Fin-Sydney-NSW-2000%3Fkeywords%3DPython%252F%2520Django%2520Developer
# https://talent.seek.com.au/
# /
# /profile/
# /career-advice/
# /companies/
# /oauth/login/?returnUrl=https%3A%2F%2Fwww.seek.com.au%2Fjobs%2Fin-Sydney-NSW-2000%3Fkeywords%3DPython%252F%2520Django%2520Developer
# /
# https://hk.jobsdb.com/
# https://www.jobstreet.co.id/
# https://www.jobstreet.com.my/
# https://www.seek.co.nz/
# https://www.jobstreet.com.ph/
# https://www.jobstreet.com.sg/
# https://th.jobsdb.com/th
# https://talent.seek.com.au/
# /
# /learning/?campaigncode=seek_banner_29&sc_trk=skj-courses-link
# ...

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="SEEK Learning" height="24" src="https://seekcdn.com/skl/laasie/logo.svg" width="120"/>
# https://seekcdn.com/skl/laasie/logo.svg
# <img alt="SEEK Learning" height="24" src="https://seekcdn.com/skl/laasie/logo.svg" width="120"/>
# https://seekcdn.com/skl/laasie/logo.svg

# %%
def contains_entry_level(tag):
    return tag and "javascript" in tag.text.lower()
matching_tags = soup.find_all(contains_entry_level)
for tag in matching_tags:
    print(tag.text.strip())
# Out:
# /* latin */
# @font-face {font-family: SeekSans;font-weight: 500 700;src: url('/static/shared-web/SEEKSans-Latin-Medium-0d7bb139d5772bf159e2d6ab7664bb49.woff2') format('woff2'),url('/static/shared-web/SEEKSans-Latin-Medium-33ee823026b461fd5f8519b9ec890974.woff') format('woff');font-display: swap;unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+20B1, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}
# @font-face {font-family: SeekSans;src: url('/static/shared-web/SEEKSans-Latin-Regular-03b2f80a92410122dbd1e0f56109c3a0.woff2') format('woff2'),url('/static/shared-web/SEEKSans-Latin-Regular-e8afb4047edc1d279a35f9c327a58db2.woff') format('woff');font-display: swap;unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+20B1, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}
# /* thai */
# ...

# %%
# Scrapping data from a table
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html'
data = requests.get(url).text
soup = BeautifulSoup(data,"html5lib")

# %%
table = soup.find('table')

# %%
def hex_to_ansi_background(hex_color):
    # Convert hex color to RGB
    r = int(hex_color[1:3], 16)
    g = int(hex_color[3:5], 16)
    b = int(hex_color[5:7], 16)
    
    # Create ANSI escape code for background color
    ansi_background = f'\033[48;2;{r};{g};{b}m'
    
    return ansi_background

# %%
def getColor(hex_color):
    BACKGROUND_COLOR = hex_to_ansi_background(hex_color)
    RESET = '\033[0m'  # Reset to default color

    # Define the dimensions of the box
    width = 10
    height = 5

    # Print the colored box
    return BACKGROUND_COLOR + " " * 3 + RESET

# %%
color = getColor('#00FF00')
print(color)

# %%
for i, row in enumerate(table.findAll('tr')):
    cols = row.findAll('td')
    color_name = cols[2].string
    color_code = str(cols[3])
    color = ''
    if i != 0:
        color = getColor(color_code)
    print(f'{color_name:20}{color_code:8}{color:4}')
# Out:
# Color Name          <td>Hex Code<br/>#RRGGBB</td>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[200], line 7
#       5 color = ''
#       6 if i != 0:
# ----> 7     color = getColor(color_code)
#       8 print(f'{color_name:20}{color_code:8}{color:4}')
#
# Cell In[191], line 2, in getColor(hex_color)
#       1 def getColor(hex_color):
# ----> 2     BACKGROUND_COLOR = hex_to_ansi_background(hex_color)
#       3     RESET = '\033'  # Reset to default color
#       5     # Define the dimensions of the box
#
# Cell In[190], line 3, in hex_to_ansi_background(hex_color)
#       1 def hex_to_ansi_background(hex_color):
#       2     # Convert hex color to RGB
# ----> 3     r = int(hex_color[1:3], 16)
#       4     g = int(hex_color[3:5], 16)
#       5     b = int(hex_color[5:7], 16)
#
# ValueError: invalid literal for int() with base 16: 'td'
